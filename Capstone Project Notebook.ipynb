# %% [markdown]
# <h1>Capstone Project </h1>
#
# ### This notebook will be used for the Coursera Applied Data Science Course Capstone Project.

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ## Creating the Dataframe

# %% [markdown]
# ### The objective of this project is to divide the most populated European Union cities into clusters. The motivation is to help people moving from a city in Europe find another city that is similar.
# ### 5 Clusters will be created based on the 20 most common venues in each City. The common venues will be obtained via Foursquare.
# ### The list of the most populated cities in the European Union is taken from a wikipedia page.

# %% [markdown]
# #### Saving the data from the wikipedia page in a dataframe. Coordinates of each city are obtained using Geocode

# %%
url = "https://en.wikipedia.org/wiki/List_of_cities_in_the_European_Union_by_population_within_city_limits"
df_website = pd.read_html(url)
df_all = df_website[0]
Cities_Names = (df_all["City"]).to_list()
Countries_Names = (df_all["Member State"]).to_list()

# %%
Cities_Latitude = []
Cities_Longitude = []
for i in range(len(Cities_Names)) :
    geolocator = Nominatim(user_agent="foursquare_agent")
    reference = Cities_Names[i]  + ", " + Countries_Names[i] # exp : Aarhus, Denmark
    location = geolocator.geocode(reference)
    latitude = location.latitude
    longitude = location.longitude
    Cities_Latitude.append(latitude)
    Cities_Longitude.append(longitude)
dict = {'City_Name': Cities_Name, 'Latitude': Cities_Latitude, 'Longitude': Cities_Longitude} 
df = pd.DataFrame(dict)
df = df.sort_values(by=['City_Name']) 
df.reset_index(drop=True, inplace=True)
df
# Out:
#             City_Name   Latitude  Longitude
# 0              Aarhus  56.149628  10.213405
# 1            Alicante  38.353738  -0.490185
# 2           Amsterdam  52.372760   4.893604
# 3             Antwerp  51.221110   4.399708
# 4              Athens  37.983941  23.728305
# 5           Barcelona  41.382894   2.177432
# 6                Bari  41.125784  16.862029
# 7              Berlin  52.517037  13.388860
# 8           Bielefeld  52.019101   8.531007
# 9              Bilbao  43.263002  -2.935004
# 10             Bochum  51.481811   7.219664
# 11            Bologna  44.493758  11.343031
# 12               Bonn  50.735851   7.100660
# 13         Bratislava  48.151699  17.109306
# 14             Bremen  53.075820   8.807165
# 15               Brno  49.192244  16.611338
# 16          Bucharest  44.436141  26.102720
# 17           Budapest  47.498382  19.040471
# 18          Bydgoszcz  53.129746  18.029370
# 19            Catania  37.502235  15.087380
# 20        Cluj-Napoca  46.769379  23.589954
# 21            Cologne  50.938361   6.959974
# 22          Constanța  44.176716  28.650760
# 23         Copenhagen  55.686724  12.570072
# 24            Craiova  44.319016  23.796561
# 25            Córdoba  37.884581  -4.776014
# 26           Dortmund  51.514227   7.465279
# 27            Dresden  51.049329  13.738144
# 28             Dublin  53.349764  -6.260273
# 29           Duisburg  51.434999   6.759562
# 30         Düsseldorf  51.225402   6.776314
# 31              Essen  51.458224   7.015817
# 32           Florence  43.769871  11.255576
# 33          Frankfurt  50.110644   8.682092
# 34             Galați  45.433822  28.054939
# 35             Gdańsk  54.361434  18.628218
# 36              Genoa  44.407260   8.933862
# 37         Gothenburg  57.707233  11.967017
# 38            Hamburg  53.550341  10.000654
# 39            Hanover  52.374478   9.738553
# 40           Helsinki  60.167488  24.942747
# 41               Iași  47.161534  27.583614
# 42          Karlsruhe  49.006870   8.403420
# 43             Kraków  50.046943  19.997153
# 44         Las Palmas  28.128874 -15.434945
# 45            Leipzig  51.340632  12.374733
# 46             Lisbon  38.707751  -9.136592
# 47             Lublin  51.218194  22.554678
# 48               Lyon  45.757814   4.832011
# 49             Madrid  40.416705  -3.703582
# 50              Malmö  55.605293  13.000157
# 51           Mannheim  49.489291   8.467310
# 52          Marseille  43.296174   5.369953
# 53              Milan  45.466800   9.190500
# 54             Munich  48.137108  11.575382
# 55             Murcia  37.992379  -1.130543
# 56             Málaga  36.721303  -4.421637
# 57            Münster  51.962510   7.625188
# 58             Nantes  47.218637  -1.554136
# 59             Naples  40.835934  14.248783
# 60               Nice  43.700936   7.268391
# 61          Nuremberg  49.453872  11.077298
# 62            Palermo  38.111227  13.352443
# 63  Palma de Mallorca  39.569582   2.650075
# 64              Paris  48.856697   2.351462
# 65            Plovdiv  42.141854  24.749930
# 66             Poznań  52.400663  16.919733
# 67             Prague  50.087465  14.421254
# 68               Riga  56.949398  24.105185
# 69               Rome  41.893320  12.482932
# 70          Rotterdam  51.922893   4.463179
# 71            Seville  37.388630  -5.995340
# 72              Sofia  42.697863  23.322179
# 73          Stockholm  59.325117  18.071093
# 74          Stuttgart  48.778449   9.180013
# 75           Szczecin  53.430182  14.550962
# 76            Tallinn  59.437216  24.745369
# 77          The Hague  52.079984   4.311346
# 78       Thessaloniki  40.640317  22.935272
# 79          Timișoara  45.753836  21.225747
# 80           Toulouse  43.604462   1.444247
# 81              Turin  45.067755   7.682489
# 82            Utrecht  52.080986   5.127684
# 83           Valencia  39.469707  -0.376335
# 84              Varna  43.206902  27.915085
# 85             Vienna  48.208354  16.372504
# 86            Vilnius  54.687046  25.282911
# 87             Warsaw  52.231958  21.006725
# 88            Wrocław  51.126311  16.978196
# 89          Wuppertal  51.264018   7.178037
# 90             Zagreb  45.813185  15.977177
# 91           Zaragoza  41.652134  -0.880943
# 92               Łódź  51.768732  19.456991

# %% [markdown]
# #### Creating a map of Europe with all cities superimposed

# %%
# Creating a map centered around Europe using Folium
europe_latitude = 53
europe_longitude = 17
europe_map = folium.Map(location=[europe_latitude, europe_longitude], zoom_start=4)
europe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_5a404a4656a74b85af61ffe628b972bb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5a404a4656a74b85af61ffe628b972bb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5a404a4656a74b85af61ffe628b972bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_5a404a4656a74b85af61ffe628b972bb%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53%2C17%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Adding the markers for the cities in the dataframe
cities = folium.map.FeatureGroup()
for lat, lng, label in zip(df.Latitude, df.Longitude, df.City_Name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, 
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.4
    ).add_to(cities)

europe_map.add_child(cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_5a404a4656a74b85af61ffe628b972bb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5a404a4656a74b85af61ffe628b972bb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5a404a4656a74b85af61ffe628b972bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_5a404a4656a74b85af61ffe628b972bb%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53%2C17%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Foursquare Credentials
CLIENT_ID = '2JBDXEOM4RNNJ3J4YFOAF5ROQHZO02QRQACZJCM3I53SBTNS' 
CLIENT_SECRET = 'LH1KEB0CXTIOUKBX0DECR5KCHVKJA3NLZCH5KXITOD5WD2EH' 
VERSION = '20180605' 
LIMIT = 200 
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2JBDXEOM4RNNJ3J4YFOAF5ROQHZO02QRQACZJCM3I53SBTNS
# CLIENT_SECRET:LH1KEB0CXTIOUKBX0DECR5KCHVKJA3NLZCH5KXITOD5WD2EH

# %% [markdown]
# #### Obtaining the most common venues for all cities

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=3000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City_Name', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
european_city_venues = getNearbyVenues(names=df['City_Name'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Aarhus
# Alicante
# Amsterdam
# Antwerp
# Athens
# Barcelona
# Bari
# Berlin
# Bielefeld
# Bilbao
# Bochum
# Bologna
# Bonn
# Bratislava
# Bremen
# Brno
# Bucharest
# Budapest
# Bydgoszcz
# Catania
# Cluj-Napoca
# Cologne
# Constanța
# Copenhagen
# Craiova
# Córdoba
# Dortmund
# Dresden
# Dublin
# Duisburg
# Düsseldorf
# Essen
# Florence
# Frankfurt
# Galați
# Gdańsk
# Genoa
# Gothenburg
# Hamburg
# Hanover
# Helsinki
# Iași
# Karlsruhe
# Kraków
# Las Palmas
# Leipzig
# Lisbon
# Lublin
# Lyon
# Madrid
# Malmö
# Mannheim
# Marseille
# Milan
# Munich
# Murcia
# Málaga
# Münster
# Nantes
# Naples
# Nice
# Nuremberg
# Palermo
# Palma de Mallorca
# Paris
# Plovdiv
# Poznań
# Prague
# Riga
# Rome
# Rotterdam
# Seville
# Sofia
# Stockholm
# Stuttgart
# Szczecin
# Tallinn
# The Hague
# Thessaloniki
# Timișoara
# Toulouse
# Turin
# Utrecht
# Valencia
# Varna
# Vienna
# Vilnius
# Warsaw
# Wrocław
# Wuppertal
# Zagreb
# Zaragoza
# Łódź

# %%
european_city_venues.groupby('City_Name').count()
# Out:
#                    City Latitude  City Longitude  Venue  Venue Latitude  \
# City_Name
# Aarhus                       100             100    100             100
# Alicante                     100             100    100             100
# Amsterdam                    100             100    100             100
# Antwerp                      100             100    100             100
# Athens                       100             100    100             100
# Barcelona                    100             100    100             100
# Bari                          88              88     88              88
# Berlin                       100             100    100             100
# Bielefeld                     66              66     66              66
# Bilbao                       100             100    100             100
# Bochum                        88              88     88              88
# Bologna                      100             100    100             100
# Bonn                         100             100    100             100
# Bratislava                   100             100    100             100
# Bremen                       100             100    100             100
# Brno                         100             100    100             100
# Bucharest                    100             100    100             100
# Budapest                     100             100    100             100
# Bydgoszcz                     57              57     57              57
# Catania                      100             100    100             100
# Cluj-Napoca                  100             100    100             100
# Cologne                      100             100    100             100
# Constanța                     97              97     97              97
# Copenhagen                   100             100    100             100
# Craiova                       97              97     97              97
# Córdoba                      100             100    100             100
# Dortmund                     100             100    100             100
# Dresden                      100             100    100             100
# Dublin                       100             100    100             100
# Duisburg                      57              57     57              57
# Düsseldorf                   100             100    100             100
# Essen                        100             100    100             100
# Florence                     100             100    100             100
# Frankfurt                    100             100    100             100
# Galați                        62              62     62              62
# Gdańsk                       100             100    100             100
# Genoa                         83              83     83              83
# Gothenburg                   100             100    100             100
# Hamburg                      100             100    100             100
# Hanover                      100             100    100             100
# Helsinki                     100             100    100             100
# Iași                         100             100    100             100
# Karlsruhe                    100             100    100             100
# Kraków                        70              70     70              70
# Las Palmas                    80              80     80              80
# Leipzig                      100             100    100             100
# Lisbon                       100             100    100             100
# Lublin                        23              23     23              23
# Lyon                         100             100    100             100
# Madrid                       100             100    100             100
# Malmö                        100             100    100             100
# Mannheim                     100             100    100             100
# Marseille                    100             100    100             100
# Milan                        100             100    100             100
# Munich                       100             100    100             100
# Murcia                        90              90     90              90
# Málaga                       100             100    100             100
# Münster                       84              84     84              84
# Nantes                       100             100    100             100
# Naples                       100             100    100             100
# Nice                         100             100    100             100
# Nuremberg                    100             100    100             100
# Palermo                      100             100    100             100
# Palma de Mallorca            100             100    100             100
# Paris                        100             100    100             100
# Plovdiv                      100             100    100             100
# Poznań                       100             100    100             100
# Prague                       100             100    100             100
# Riga                         100             100    100             100
# Rome                         100             100    100             100
# Rotterdam                    100             100    100             100
# Seville                      100             100    100             100
# Sofia                        100             100    100             100
# Stockholm                    100             100    100             100
# Stuttgart                    100             100    100             100
# Szczecin                      58              58     58              58
# Tallinn                      100             100    100             100
# The Hague                    100             100    100             100
# Thessaloniki                 100             100    100             100
# Timișoara                    100             100    100             100
# Toulouse                     100             100    100             100
# Turin                        100             100    100             100
# Utrecht                      100             100    100             100
# Valencia                     100             100    100             100
# Varna                        100             100    100             100
# Vienna                       100             100    100             100
# Vilnius                      100             100    100             100
# Warsaw                       100             100    100             100
# Wrocław                       81              81     81              81
# Wuppertal                     88              88     88              88
# Zagreb                       100             100    100             100
# Zaragoza                     100             100    100             100
# Łódź                         100             100    100             100
#
#                    Venue Longitude  Venue Category
# City_Name
# Aarhus                         100             100
# Alicante                       100             100
# Amsterdam                      100             100
# Antwerp                        100             100
# Athens                         100             100
# Barcelona                      100             100
# Bari                            88              88
# Berlin                         100             100
# Bielefeld                       66              66
# Bilbao                         100             100
# Bochum                          88              88
# Bologna                        100             100
# Bonn                           100             100
# Bratislava                     100             100
# Bremen                         100             100
# Brno                           100             100
# Bucharest                      100             100
# Budapest                       100             100
# Bydgoszcz                       57              57
# Catania                        100             100
# Cluj-Napoca                    100             100
# Cologne                        100             100
# Constanța                       97              97
# Copenhagen                     100             100
# Craiova                         97              97
# Córdoba                        100             100
# Dortmund                       100             100
# Dresden                        100             100
# Dublin                         100             100
# Duisburg                        57              57
# Düsseldorf                     100             100
# Essen                          100             100
# Florence                       100             100
# Frankfurt                      100             100
# Galați                          62              62
# Gdańsk                         100             100
# Genoa                           83              83
# Gothenburg                     100             100
# Hamburg                        100             100
# Hanover                        100             100
# Helsinki                       100             100
# Iași                           100             100
# Karlsruhe                      100             100
# Kraków                          70              70
# Las Palmas                      80              80
# Leipzig                        100             100
# Lisbon                         100             100
# Lublin                          23              23
# Lyon                           100             100
# Madrid                         100             100
# Malmö                          100             100
# Mannheim                       100             100
# Marseille                      100             100
# Milan                          100             100
# Munich                         100             100
# Murcia                          90              90
# Málaga                         100             100
# Münster                         84              84
# Nantes                         100             100
# Naples                         100             100
# Nice                           100             100
# Nuremberg                      100             100
# Palermo                        100             100
# Palma de Mallorca              100             100
# Paris                          100             100
# Plovdiv                        100             100
# Poznań                         100             100
# Prague                         100             100
# Riga                           100             100
# Rome                           100             100
# Rotterdam                      100             100
# Seville                        100             100
# Sofia                          100             100
# Stockholm                      100             100
# Stuttgart                      100             100
# Szczecin                        58              58
# Tallinn                        100             100
# The Hague                      100             100
# Thessaloniki                   100             100
# Timișoara                      100             100
# Toulouse                       100             100
# Turin                          100             100
# Utrecht                        100             100
# Valencia                       100             100
# Varna                          100             100
# Vienna                         100             100
# Vilnius                        100             100
# Warsaw                         100             100
# Wrocław                         81              81
# Wuppertal                       88              88
# Zagreb                         100             100
# Zaragoza                       100             100
# Łódź                           100             100

# %% [markdown]
# #### Encoding and getting the 20 most common venues for each city

# %%
# one hot encoding
european_city_onehot = pd.get_dummies(european_city_venues[['Venue Category']], prefix="", prefix_sep="")

# add city name column back to dataframe
european_city_onehot['City_Name'] = european_city_venues['City_Name'] 

# move city name column to the first column
fixed_columns = [european_city_onehot.columns[-1]] + list(european_city_onehot.columns[:-1])
european_city_onehot = european_city_onehot[fixed_columns]

european_city_grouped = european_city_onehot.groupby('City_Name').mean().reset_index()
european_city_grouped.shape
# Out:
# (93, 411)

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City_Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
european_city_venues_sorted = pd.DataFrame(columns=columns)
european_city_venues_sorted['City_Name'] = european_city_grouped['City_Name']

for ind in np.arange(european_city_grouped.shape[0]):
    european_city_venues_sorted.iloc[ind, 1:] = return_most_common_venues(european_city_grouped.iloc[ind, :], num_top_venues)

european_city_venues_sorted.shape
# Out:
# (93, 21)

# %% [markdown]
# #### Creating the clusters and visualizing them in the map

# %%
# set number of clusters
kclusters = 5

european_city_grouped_clustering = european_city_grouped.drop('City_Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(european_city_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:20]
# Out:
# array([0, 2, 4, 4, 0, 2, 3, 4, 4, 2, 4, 3, 0, 0, 4, 0, 4, 4, 4, 3])

# %%
# add clustering labels
european_city_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
# merge european_city_grouped with df to add latitude/longitude for each city
european_city_merged = df
european_city_merged = european_city_merged.join(european_city_venues_sorted.set_index('City_Name'), on='City_Name')
european_city_merged.head(20)
# Out:
#      City_Name   Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0       Aarhus  56.149628  10.213405               0                  Café
# 1     Alicante  38.353738  -0.490185               2      Tapas Restaurant
# 2    Amsterdam  52.372760   4.893604               4           Coffee Shop
# 3      Antwerp  51.221110   4.399708               4           Coffee Shop
# 4       Athens  37.983941  23.728305               0           Coffee Shop
# 5    Barcelona  41.382894   2.177432               2                 Hotel
# 6         Bari  41.125784  16.862029               3           Pizza Place
# 7       Berlin  52.517037  13.388860               4           Coffee Shop
# 8    Bielefeld  52.019101   8.531007               4                   Bar
# 9       Bilbao  43.263002  -2.935004               2      Tapas Restaurant
# 10      Bochum  51.481811   7.219664               4           Supermarket
# 11     Bologna  44.493758  11.343031               3        Ice Cream Shop
# 12        Bonn  50.735851   7.100660               0                  Café
# 13  Bratislava  48.151699  17.109306               0                  Café
# 14      Bremen  53.075820   8.807165               4                 Hotel
# 15        Brno  49.192244  16.611338               0                  Café
# 16   Bucharest  44.436141  26.102720               4           Coffee Shop
# 17    Budapest  47.498382  19.040471               4           Coffee Shop
# 18   Bydgoszcz  53.129746  18.029370               4                 Hotel
# 19     Catania  37.502235  15.087380               3    Italian Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 0            Coffee Shop              Wine Bar                    Bar
# 1             Restaurant    Spanish Restaurant                  Plaza
# 2                  Hotel                   Bar             Restaurant
# 3         Clothing Store                   Bar                  Plaza
# 4                   Café         Historic Site           Dessert Shop
# 5       Tapas Restaurant           Coffee Shop                  Plaza
# 6     Italian Restaurant                   Pub                    Bar
# 7              Bookstore                 Hotel             Art Museum
# 8            Supermarket                  Café                   Park
# 9                  Plaza            Restaurant     Spanish Restaurant
# 10                Bakery               Theater         Ice Cream Shop
# 11    Italian Restaurant                 Plaza                   Park
# 12    Italian Restaurant           Supermarket                 Bakery
# 13           Coffee Shop                  Park                  Plaza
# 14    Italian Restaurant                   Bar                   Café
# 15           Coffee Shop                   Pub  Vietnamese Restaurant
# 16                 Hotel                 Plaza    Romanian Restaurant
# 17                Bakery                 Hotel            Pizza Place
# 18            Restaurant                  Café       Sushi Restaurant
# 19           Pizza Place                  Café                  Plaza
#
#         5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 0                        Park         French Restaurant                 Plaza
# 1                 Coffee Shop  Mediterranean Restaurant        Ice Cream Shop
# 2                      Bakery        Italian Restaurant                 Plaza
# 3                Cocktail Bar         French Restaurant    Belgian Restaurant
# 4                Gourmet Shop                  Boutique                   Bar
# 5                Burger Joint                 Bookstore           Pizza Place
# 6                        Café                     Hotel            Restaurant
# 7         Monument / Landmark              Concert Hall                 Plaza
# 8   Middle Eastern Restaurant                     Hotel      Asian Restaurant
# 9                        Café                      Park                 Hotel
# 10                   Bus Stop                      Park          Intersection
# 11                      Hotel                      Café           Coffee Shop
# 12                      Plaza          Asian Restaurant           Coffee Shop
# 13                   Wine Bar                     Hotel       Thai Restaurant
# 14                Supermarket                 Drugstore        Ice Cream Shop
# 15                       Park                       Bar                 Hotel
# 16                  Gastropub                       Pub            Restaurant
# 17                 Playground       Indie Movie Theater               Theater
# 18       Fast Food Restaurant               Coffee Shop        Clothing Store
# 19              Historic Site              Dessert Shop       Bed & Breakfast
#
#             8th Most Common Venue 9th Most Common Venue  \
# 0              Seafood Restaurant            Restaurant
# 1                     Pizza Place    Italian Restaurant
# 2                           Canal                  Café
# 3                          Bakery              Boutique
# 4                 Meze Restaurant             Bookstore
# 5                        Wine Bar          Cocktail Bar
# 6                  Ice Cream Shop                 Plaza
# 7                            Park         Historic Site
# 8              Italian Restaurant          Burger Joint
# 9                   Deli / Bodega              Wine Bar
# 10                   Concert Hall      Tapas Restaurant
# 11                 Sandwich Place             Bookstore
# 12                            Pub      Tapas Restaurant
# 13  Vegetarian / Vegan Restaurant                Bistro
# 14              German Restaurant    Falafel Restaurant
# 15             Italian Restaurant  Gym / Fitness Center
# 16                         Bakery          Dessert Shop
# 17                   Dessert Shop    Italian Restaurant
# 18    Eastern European Restaurant         Historic Site
# 19  Vegetarian / Vegan Restaurant          Cocktail Bar
#
#    10th Most Common Venue    11th Most Common Venue 12th Most Common Venue  \
# 0                  Forest          Botanical Garden          Grocery Store
# 1               Bookstore                     Hotel            Supermarket
# 2           Deli / Bodega           Organic Grocery   Marijuana Dispensary
# 3                 Theater                    Bistro     Italian Restaurant
# 4                Wine Bar                      Park         Ice Cream Shop
# 5      Spanish Restaurant                Donut Shop     Italian Restaurant
# 6            Cocktail Bar        Seafood Restaurant            Beer Garden
# 7       Outdoor Sculpture                    Bakery            Art Gallery
# 8            Tram Station  Mediterranean Restaurant                 Bakery
# 9                  Lounge                    Museum                    Bar
# 10      German Restaurant          Sushi Restaurant       Asian Restaurant
# 11                    Bar  Mediterranean Restaurant      Electronics Store
# 12       Sushi Restaurant                    Museum                   Park
# 13         Ice Cream Shop               Art Gallery         Farmers Market
# 14             Restaurant                     Plaza          Burrito Place
# 15           Burger Joint                  Tea Room              Juice Bar
# 16              Bookstore               Pizza Place              Roof Deck
# 17         Breakfast Spot      Gym / Fitness Center              Wine Shop
# 18                Stadium            Ice Cream Shop            Gas Station
# 19           Burger Joint                       Pub                 Hostel
#
#    13th Most Common Venue 14th Most Common Venue  \
# 0                   Hotel     Italian Restaurant
# 1                    Café                Theater
# 2            Dessert Shop   Caribbean Restaurant
# 3           Women's Store         Lingerie Store
# 4               Gift Shop       Sushi Restaurant
# 5     Monument / Landmark           Camera Store
# 6                    Park            Coffee Shop
# 7   Vietnamese Restaurant        Organic Grocery
# 8              Restaurant      German Restaurant
# 9       Outdoor Sculpture              Gastropub
# 10                   Café                Butcher
# 11               Beer Bar            Pizza Place
# 12         Ice Cream Shop           Cocktail Bar
# 13     Italian Restaurant      Health Food Store
# 14                 Bakery                   Park
# 15           Cocktail Bar                  Plaza
# 16           Cocktail Bar                   Café
# 17           Gourmet Shop          Historic Site
# 18                Theater            Supermarket
# 19    Japanese Restaurant               Fountain
#
#            15th Most Common Venue     16th Most Common Venue  \
# 0                  Sandwich Place             Ice Cream Shop
# 1   Vegetarian / Vegan Restaurant        Japanese Restaurant
# 2                          Museum               Cocktail Bar
# 3              Frozen Yogurt Shop                  Bookstore
# 4                           Plaza           Greek Restaurant
# 5        Mediterranean Restaurant             Ice Cream Shop
# 6                      Steakhouse                    Theater
# 7                         Theater                     Bistro
# 8                           Plaza                     Garden
# 9                          Bakery         Seafood Restaurant
# 10                   Burger Joint                  Bookstore
# 11                       Wine Bar        Monument / Landmark
# 12                        Theater           Greek Restaurant
# 13                   Burger Joint      Vietnamese Restaurant
# 14                   Burger Joint  Middle Eastern Restaurant
# 15              Indian Restaurant            Organic Grocery
# 16                         Bistro                Supermarket
# 17                       Tea Room                       Park
# 18     Modern European Restaurant             Breakfast Spot
# 19                      Bookstore          Trattoria/Osteria
#
#      17th Most Common Venue     18th Most Common Venue 19th Most Common Venue  \
# 0   Scandinavian Restaurant               Burger Joint             Bike Trail
# 1         Paella Restaurant                   Wine Bar                  Beach
# 2                   Theater          French Restaurant           Burger Joint
# 3           Bubble Tea Shop     Furniture / Home Store               Friterie
# 4                   Theater         Falafel Restaurant               Pie Shop
# 5                 Wine Shop          Food & Drink Shop                 Museum
# 6              Gourmet Shop               Cupcake Shop                 Bistro
# 7            Ice Cream Shop             History Museum           Gourmet Shop
# 8          Sushi Restaurant                 Steakhouse       Tapas Restaurant
# 9                  Beer Bar             Clothing Store           Cocktail Bar
# 10           Scenic Lookout                   Beer Bar      Food & Drink Shop
# 11       Seafood Restaurant             Scenic Lookout           Cocktail Bar
# 12               Restaurant  Middle Eastern Restaurant          Movie Theater
# 13                 Creperie                Pizza Place              Bookstore
# 14                     Lake                     Market         Soccer Stadium
# 15         Czech Restaurant               Dessert Shop            Cheese Shop
# 16                     Park                  Monastery     Italian Restaurant
# 17                    Plaza             Sandwich Place             Restaurant
# 18             Burger Joint                  Multiplex                 Museum
# 19                    Hotel   Mediterranean Restaurant     Chinese Restaurant
#
#    20th Most Common Venue
# 0             Beer Garden
# 1          Sandwich Place
# 2          Chocolate Shop
# 3          Breakfast Spot
# 4            Cocktail Bar
# 5                     Spa
# 6               Gastropub
# 7              Restaurant
# 8           Big Box Store
# 9          Soccer Stadium
# 10               Mountain
# 11                 Bistro
# 12   Gym / Fitness Center
# 13          Design Studio
# 14           Soccer Field
# 15                Theater
# 16                Theater
# 17      Outdoor Sculpture
# 18          Shopping Mall
# 19             Steakhouse

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=4)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(european_city_merged['Latitude'], european_city_merged['Longitude'], european_city_merged['City_Name'], european_city_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_743b147c7d974f01bb527ae69c5fbe41%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_743b147c7d974f01bb527ae69c5fbe41%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_743b147c7d974f01bb527ae69c5fbe41%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_743b147c7d974f01bb527ae69c5fbe41%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B45.4338215%2C28.0549395%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
european_city_merged.loc[european_city_merged['Cluster Labels'] == 0, european_city_merged.columns[[0] + list(range(5, european_city_merged.shape[1]))]]
# Out:
#        City_Name 2nd Most Common Venue 3rd Most Common Venue  \
# 0         Aarhus           Coffee Shop              Wine Bar
# 4         Athens                  Café         Historic Site
# 12          Bonn    Italian Restaurant           Supermarket
# 13    Bratislava           Coffee Shop                  Park
# 15          Brno           Coffee Shop                   Pub
# 26      Dortmund          Burger Joint                  Park
# 28        Dublin                  Café                   Pub
# 29      Duisburg            Restaurant     German Restaurant
# 30    Düsseldorf                  Park           Coffee Shop
# 33     Frankfurt                 Plaza                  Park
# 39       Hanover    Italian Restaurant                  Café
# 41          Iași           Coffee Shop                 Hotel
# 42     Karlsruhe     German Restaurant                  Park
# 45       Leipzig           Zoo Exhibit                 Hotel
# 50         Malmö           Coffee Shop                Bakery
# 51      Mannheim                  Park                 Hotel
# 54        Munich                 Plaza                 Hotel
# 57       Münster           Coffee Shop                  Park
# 61     Nuremberg                 Hotel          Burger Joint
# 66        Poznań     Polish Restaurant    Italian Restaurant
# 67        Prague                  Park               Theater
# 75      Szczecin               Brewery                  Café
# 78  Thessaloniki          Dessert Shop                 Hotel
# 79     Timișoara            Restaurant           Coffee Shop
# 89     Wuppertal           Supermarket                   Bar
# 90        Zagreb                 Plaza                   Bar
#
#             4th Most Common Venue    5th Most Common Venue  \
# 0                             Bar                     Park
# 4                    Dessert Shop             Gourmet Shop
# 12                         Bakery                    Plaza
# 13                          Plaza                 Wine Bar
# 15          Vietnamese Restaurant                     Park
# 26                      Nightclub                      Bar
# 28                           Park             Burger Joint
# 29  Vegetarian / Vegan Restaurant                    River
# 30                   Cocktail Bar              Pizza Place
# 33                         Bakery           Apple Wine Pub
# 39                         Bakery              Supermarket
# 41             Italian Restaurant      Romanian Restaurant
# 42  Vegetarian / Vegan Restaurant       Italian Restaurant
# 45                      Nightclub                    Plaza
# 50                          Hotel  Scandinavian Restaurant
# 51             Italian Restaurant                      Bar
# 54                   Cocktail Bar           Ice Cream Shop
# 57                    Supermarket       Italian Restaurant
# 61                    Coffee Shop          Thai Restaurant
# 66                           Park               Restaurant
# 67                   Burger Joint                   Garden
# 75                          Diner           Ice Cream Shop
# 78                    Coffee Shop             Cocktail Bar
# 79                   Dessert Shop                   Bakery
# 89           Fast Food Restaurant           Clothing Store
# 90                     Restaurant             Dessert Shop
#
#        6th Most Common Venue 7th Most Common Venue  \
# 0          French Restaurant                 Plaza
# 4                   Boutique                   Bar
# 12          Asian Restaurant           Coffee Shop
# 13                     Hotel       Thai Restaurant
# 15                       Bar                 Hotel
# 26  Mediterranean Restaurant    Italian Restaurant
# 28        Italian Restaurant          Cocktail Bar
# 29           Thai Restaurant        Ice Cream Shop
# 30                     Plaza   Japanese Restaurant
# 33        Italian Restaurant                   Bar
# 39                      Park                   Pub
# 41                       Pub  Fast Food Restaurant
# 42               Coffee Shop             Drugstore
# 45                      Park            Restaurant
# 50                  Wine Bar                   Pub
# 51     Vietnamese Restaurant     German Restaurant
# 54               Coffee Shop          Burger Joint
# 57                     Hotel                 Plaza
# 61                      Park           Pizza Place
# 66               Coffee Shop        Breakfast Spot
# 67              Noodle House        Scenic Lookout
# 75                     Plaza            Restaurant
# 78                       Bar              Wine Bar
# 79                      Park           Salad Place
# 89               Coffee Shop                  Park
# 90  Mediterranean Restaurant               Theater
#
#             8th Most Common Venue     9th Most Common Venue  \
# 0              Seafood Restaurant                Restaurant
# 4                 Meze Restaurant                 Bookstore
# 12                            Pub          Tapas Restaurant
# 13  Vegetarian / Vegan Restaurant                    Bistro
# 15             Italian Restaurant      Gym / Fitness Center
# 26                 Ice Cream Shop         German Restaurant
# 28                      Bookstore                   Theater
# 29              Trattoria/Osteria        Turkish Restaurant
# 30             Italian Restaurant          Sushi Restaurant
# 33                    Coffee Shop     Vietnamese Restaurant
# 39                          Plaza               Pizza Place
# 41                     Restaurant  Mediterranean Restaurant
# 42                Organic Grocery                     Plaza
# 45             Chinese Restaurant               Coffee Shop
# 50             Italian Restaurant              Burger Joint
# 51                          Plaza        Turkish Restaurant
# 54                    Pastry Shop                  Tea Room
# 57                   Burger Joint                 Nightclub
# 61                         Bakery          Greek Restaurant
# 66               Sushi Restaurant                    Bakery
# 67                         Bakery                    Island
# 75                   Burger Joint      Fast Food Restaurant
# 78                 Clothing Store                    Bakery
# 79                    Pizza Place                    Bistro
# 89             Italian Restaurant                  Bus Stop
# 90                           Park                    Bistro
#
#       10th Most Common Venue 11th Most Common Venue  \
# 0                     Forest       Botanical Garden
# 4                   Wine Bar                   Park
# 12          Sushi Restaurant                 Museum
# 13            Ice Cream Shop            Art Gallery
# 15              Burger Joint               Tea Room
# 26        Turkish Restaurant             Restaurant
# 28             Historic Site              Irish Pub
# 29          Asian Restaurant     Seafood Restaurant
# 30                    Bakery                Brewery
# 33                 Gastropub                 Lounge
# 39         German Restaurant         Farmers Market
# 41                 BBQ Joint                    Bar
# 42               Supermarket                 Palace
# 45                    Museum            Record Shop
# 50                Restaurant                   Park
# 51               Coffee Shop              Nightclub
# 54                Art Museum  Vietnamese Restaurant
# 57  Mediterranean Restaurant      German Restaurant
# 61         Trattoria/Osteria     Turkish Restaurant
# 66                     Hotel         Ice Cream Shop
# 67               Art Gallery             Restaurant
# 75               Snack Place          Movie Theater
# 78              Burger Joint          Bougatsa Shop
# 79                    Lounge       Pedestrian Plaza
# 89              Burger Joint             Restaurant
# 90               Coffee Shop          Historic Site
#
#            12th Most Common Venue         13th Most Common Venue  \
# 0                   Grocery Store                          Hotel
# 4                  Ice Cream Shop                      Gift Shop
# 12                           Park                 Ice Cream Shop
# 13                 Farmers Market             Italian Restaurant
# 15                      Juice Bar                   Cocktail Bar
# 26                Thai Restaurant                            Pub
# 28                          Plaza                          Hotel
# 29                    Coffee Shop                         Bakery
# 30                     Art Museum                     Beer Store
# 33              French Restaurant                     Art Museum
# 39                    Pastry Shop                 Ice Cream Shop
# 41                         Lounge  Vegetarian / Vegan Restaurant
# 42      Middle Eastern Restaurant                            Bar
# 45                            Pub                    Opera House
# 50             Falafel Restaurant                   Cocktail Bar
# 51                      Drugstore                         Lounge
# 54              German Restaurant                     Restaurant
# 57                            Bar             Athletics & Sports
# 61  Vegetarian / Vegan Restaurant                        Brewery
# 66                       Beer Bar                            Pub
# 67                   Cocktail Bar            Indie Movie Theater
# 75                            Pub                 Breakfast Spot
# 78                   Gourmet Shop                    Pizza Place
# 79                        Theater                         Hostel
# 89               Greek Restaurant                  Grocery Store
# 90                    Pizza Place                    Escape Room
#
#    14th Most Common Venue 15th Most Common Venue       16th Most Common Venue  \
# 0      Italian Restaurant         Sandwich Place               Ice Cream Shop
# 4        Sushi Restaurant                  Plaza             Greek Restaurant
# 12           Cocktail Bar                Theater             Greek Restaurant
# 13      Health Food Store           Burger Joint        Vietnamese Restaurant
# 15                  Plaza      Indian Restaurant              Organic Grocery
# 26       Sushi Restaurant       Doner Restaurant                  Supermarket
# 28    Indie Movie Theater      Food & Drink Shop                    Multiplex
# 29                    Bar              Drugstore                         Park
# 30     Frozen Yogurt Shop      French Restaurant                  Beer Garden
# 33       Sushi Restaurant                  Hotel                       Bistro
# 39       Greek Restaurant       Sushi Restaurant   Modern European Restaurant
# 41         Clothing Store    Fried Chicken Joint                        Plaza
# 42                Theater                    Gym         Gym / Fitness Center
# 45         Ice Cream Shop     Italian Restaurant                      Theater
# 50            Salad Place                Theater                        Plaza
# 51           Cupcake Shop         Science Museum               Scenic Lookout
# 54            Opera House            Pizza Place                      Theater
# 57                Theater                 Bakery                    Drugstore
# 61                    Bar             Steakhouse           Italian Restaurant
# 66                 Museum         Massage Studio                          Bar
# 67            Coffee Shop           Dessert Shop            French Restaurant
# 75          Shopping Mall   Brazilian Restaurant                  Supermarket
# 78                 Church         Ice Cream Shop              Bed & Breakfast
# 79              Bookstore   Fast Food Restaurant               Sandwich Place
# 89                 Bakery   Gym / Fitness Center                          Pub
# 90          Movie Theater                  Hotel  Eastern European Restaurant
#
#      17th Most Common Venue     18th Most Common Venue  \
# 0   Scandinavian Restaurant               Burger Joint
# 4                   Theater         Falafel Restaurant
# 12               Restaurant  Middle Eastern Restaurant
# 13                 Creperie                Pizza Place
# 15         Czech Restaurant               Dessert Shop
# 26              Coffee Shop                     Museum
# 28              Gelato Shop                 Taco Place
# 29              Supermarket                Beer Garden
# 30    Vietnamese Restaurant           Pedestrian Plaza
# 33               Waterfront                   Wine Bar
# 39        Indian Restaurant                        Bar
# 41         Pedestrian Plaza               Dessert Shop
# 42       Chinese Restaurant                     Museum
# 45        German Restaurant         Falafel Restaurant
# 50   Furniture / Home Store                  Hotel Bar
# 51                Irish Pub                Snack Place
# 54       Italian Restaurant                Manti Place
# 57           Ice Cream Shop        Indie Movie Theater
# 61           History Museum                     Castle
# 66             Burger Joint              Movie Theater
# 67               Steakhouse                      Plaza
# 75                   Market                     Bistro
# 78                  Taverna                 Donut Shop
# 79                Gastropub                   Wine Bar
# 89        German Restaurant                Pizza Place
# 90                   Hostel                  Nightclub
#
#          19th Most Common Venue    20th Most Common Venue
# 0                    Bike Trail               Beer Garden
# 4                      Pie Shop              Cocktail Bar
# 12                Movie Theater      Gym / Fitness Center
# 13                    Bookstore             Design Studio
# 15                  Cheese Shop                   Theater
# 26               Soccer Stadium                     Hotel
# 28                      Gay Bar                    Bistro
# 29  Eastern European Restaurant              Liquor Store
# 30             Ramen Restaurant                     Hotel
# 33            Indian Restaurant        Falafel Restaurant
# 39                  Opera House                 Multiplex
# 41                         Park          Sushi Restaurant
# 42           Turkish Restaurant  Mediterranean Restaurant
# 45                       Bistro               Beer Garden
# 50   Modern European Restaurant                Food Court
# 51                Shopping Mall              Skating Rink
# 54                    Surf Spot               Supermarket
# 57                        Diner              Soccer Field
# 61            Polish Restaurant              Concert Hall
# 66                    Juice Bar               Pizza Place
# 67                  Beer Garden                     Hotel
# 75       Furniture / Home Store                  Tea Room
# 78             Greek Restaurant                Restaurant
# 79                          Pub       Romanian Restaurant
# 89                         Pool          Asian Restaurant
# 90                 Burger Joint          Pedestrian Plaza

# %%
european_city_merged.loc[european_city_merged['Cluster Labels'] == 1, european_city_merged.columns[[0] + list(range(5, european_city_merged.shape[1]))]]
# Out:
#     City_Name 2nd Most Common Venue 3rd Most Common Venue  \
# 27    Dresden                Bakery                 Hotel
# 46     Lisbon                Hostel        Scenic Lookout
# 48       Lyon     French Restaurant                  Café
# 52  Marseille     French Restaurant                 Plaza
# 58     Nantes                   Bar                Bakery
# 60       Nice                 Beach                 Hotel
# 64      Paris     French Restaurant                 Hotel
# 80   Toulouse                 Plaza                   Bar
# 85     Vienna                 Hotel   Austrian Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 27           Supermarket      German Restaurant            Restaurant
# 46                 Hotel  Portuguese Restaurant            Restaurant
# 48                   Bar        Lyonese Bouchon              Wine Bar
# 52                   Bar   Provençal Restaurant           Supermarket
# 58                 Plaza            Pizza Place            Restaurant
# 60    Italian Restaurant                   Café                  Park
# 64                Bakery               Wine Bar                Garden
# 80                   Pub                 Garden                 Hotel
# 85           Coffee Shop             Art Museum                  Park
#
#    7th Most Common Venue          8th Most Common Venue 9th Most Common Venue  \
# 27                Museum  Vegetarian / Vegan Restaurant           Coffee Shop
# 46              Wine Bar                           Café                Bakery
# 48          Cocktail Bar                          Hotel        Ice Cream Shop
# 52                  Park               Tapas Restaurant            Art Museum
# 58                Bistro                  Historic Site           Coffee Shop
# 60        Ice Cream Shop       Mediterranean Restaurant           Pizza Place
# 64         Historic Site                   Cocktail Bar           Coffee Shop
# 80          Burger Joint                    Coffee Shop              Tea Room
# 85                  Café                   Concert Hall            Restaurant
#
#    10th Most Common Venue         11th Most Common Venue  \
# 27              Drugstore                           Café
# 46                    Bar  Vegetarian / Vegan Restaurant
# 48     Italian Restaurant                  Historic Site
# 52            Pizza Place                         Lounge
# 58           Concert Hall                         Garden
# 60          Historic Site                          Plaza
# 64             Art Museum                    Art Gallery
# 80    Japanese Restaurant                     Art Museum
# 85           Skating Rink                         Church
#
#            12th Most Common Venue 13th Most Common Venue  \
# 27                         Palace       Greek Restaurant
# 46                         Church                 Garden
# 48                     Art Museum                 Museum
# 52                         Bakery          Shopping Mall
# 58               Greek Restaurant             Theme Park
# 60                         Bakery             Art Museum
# 64  Vegetarian / Vegan Restaurant         Sandwich Place
# 80                     Restaurant                   Café
# 85                         Palace      French Restaurant
#
#    14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 27            Beer Garden            Art Gallery                  Field
# 46           Gourmet Shop           Burger Joint         Ice Cream Shop
# 48       Pedestrian Plaza            Coffee Shop                    Pub
# 52                    Bay                  Beach        Bed & Breakfast
# 58      Indian Restaurant                  Hotel               Wine Bar
# 60             Restaurant           Cupcake Shop                 Lounge
# 64               Fountain              Bookstore         Ice Cream Shop
# 80           Tram Station         Ice Cream Shop               Wine Bar
# 85                 Bakery               Tea Room       Pedestrian Plaza
#
#    17th Most Common Venue 18th Most Common Venue  19th Most Common Venue  \
# 27          Historic Site                   Park        Doner Restaurant
# 46             Food Court   Brazilian Restaurant            Concert Hall
# 48                 Bistro                 Church               Bookstore
# 52     Seafood Restaurant          Historic Site                  Church
# 58             Food Court      Fish & Chips Shop           Movie Theater
# 60         Scenic Lookout     Seafood Restaurant          Chocolate Shop
# 64         Breakfast Spot            Cheese Shop  Furniture / Home Store
# 80            Comedy Club         Soccer Stadium              Steakhouse
# 85    Japanese Restaurant      Electronics Store                Fountain
#
#    20th Most Common Venue
# 27    Monument / Landmark
# 46              Bookstore
# 48             Public Art
# 52             Steakhouse
# 58                 Castle
# 60           Cocktail Bar
# 64          Souvlaki Shop
# 80         Science Museum
# 85            Supermarket

# %%
european_city_merged.loc[european_city_merged['Cluster Labels'] == 2, european_city_merged.columns[[0] + list(range(5, european_city_merged.shape[1]))]]
# Out:
#             City_Name 2nd Most Common Venue 3rd Most Common Venue  \
# 1            Alicante            Restaurant    Spanish Restaurant
# 5           Barcelona      Tapas Restaurant           Coffee Shop
# 9              Bilbao                 Plaza            Restaurant
# 25            Córdoba                 Hotel      Tapas Restaurant
# 44         Las Palmas            Restaurant      Tapas Restaurant
# 49             Madrid                 Hotel            Restaurant
# 55             Murcia            Restaurant                 Plaza
# 56             Málaga            Restaurant      Tapas Restaurant
# 63  Palma de Mallorca      Tapas Restaurant            Restaurant
# 71            Seville    Spanish Restaurant                 Plaza
# 83           Valencia                  Park                Garden
# 91           Zaragoza    Spanish Restaurant                  Park
#
#        4th Most Common Venue     5th Most Common Venue  \
# 1                      Plaza               Coffee Shop
# 5                      Plaza              Burger Joint
# 9         Spanish Restaurant                      Café
# 25                      Park                     Plaza
# 44                      Park                      Café
# 49                      Café                    Hostel
# 55                     Hotel  Mediterranean Restaurant
# 56        Spanish Restaurant                     Hotel
# 63  Mediterranean Restaurant                     Plaza
# 71                      Café                     Hotel
# 83                Restaurant        Italian Restaurant
# 91                     Hotel                Restaurant
#
#        6th Most Common Venue     7th Most Common Venue 8th Most Common Venue  \
# 1   Mediterranean Restaurant            Ice Cream Shop           Pizza Place
# 5                  Bookstore               Pizza Place              Wine Bar
# 9                       Park                     Hotel         Deli / Bodega
# 25                       Bar                Restaurant               Brewery
# 44                     Beach  Mediterranean Restaurant                   Bar
# 49        Spanish Restaurant                   Theater      Tapas Restaurant
# 55                      Café               Coffee Shop      Tapas Restaurant
# 56                     Beach        Seafood Restaurant            Art Museum
# 63        Spanish Restaurant               Coffee Shop                 Diner
# 71                      Park                   Theater                   Bar
# 83                     Hotel                    Museum        Ice Cream Shop
# 91                     Plaza                    Bistro           Coffee Shop
#
#             9th Most Common Venue    10th Most Common Venue  \
# 1              Italian Restaurant                 Bookstore
# 5                    Cocktail Bar        Spanish Restaurant
# 9                        Wine Bar                    Lounge
# 25                 History Museum                  Wine Bar
# 44  Vegetarian / Vegan Restaurant               Supermarket
# 49                     Art Museum               Pizza Place
# 55                            Gym                      Park
# 56                           Café                     Plaza
# 63                          Hotel                    Bakery
# 71                      Gastropub  Mediterranean Restaurant
# 83                         Market             Historic Site
# 91                            Bar  Mediterranean Restaurant
#
#            11th Most Common Venue    12th Most Common Venue  \
# 1                           Hotel               Supermarket
# 5                      Donut Shop        Italian Restaurant
# 9                          Museum                       Bar
# 25                   Cocktail Bar            Ice Cream Shop
# 44             Seafood Restaurant                     Plaza
# 49  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 55  Vegetarian / Vegan Restaurant       Japanese Restaurant
# 56                   Burger Joint                    Bakery
# 63                            Bar        Chinese Restaurant
# 71                  Historic Site                    Garden
# 83                    Coffee Shop          Tapas Restaurant
# 91                        Brewery                   Theater
#
#    13th Most Common Venue    14th Most Common Venue  \
# 1                    Café                   Theater
# 5     Monument / Landmark              Camera Store
# 9       Outdoor Sculpture                 Gastropub
# 25                Theater                       Spa
# 44                  Hotel             Shopping Mall
# 49        Other Nightlife            Clothing Store
# 55     Seafood Restaurant                 Nightclub
# 56          Historic Site              Dessert Shop
# 63    Japanese Restaurant                      Park
# 71          Deli / Bodega    Argentinian Restaurant
# 83     Spanish Restaurant  Mediterranean Restaurant
# 91                 Bakery                       Gym
#
#            15th Most Common Venue 16th Most Common Venue  \
# 1   Vegetarian / Vegan Restaurant    Japanese Restaurant
# 5        Mediterranean Restaurant         Ice Cream Shop
# 9                          Bakery     Seafood Restaurant
# 25                     Comic Shop                   Café
# 44                    Coffee Shop           Burger Joint
# 49                   Cocktail Bar           Gourmet Shop
# 55                        Stadium          Grocery Store
# 56       Bike Rental / Bike Share       Sushi Restaurant
# 63                 Ice Cream Shop              Bookstore
# 71                   Cocktail Bar                 Hostel
# 83                           Café      Electronics Store
# 91                   Burger Joint                   Café
#
#     17th Most Common Venue 18th Most Common Venue    19th Most Common Venue  \
# 1        Paella Restaurant               Wine Bar                     Beach
# 5                Wine Shop      Food & Drink Shop                    Museum
# 9                 Beer Bar         Clothing Store              Cocktail Bar
# 25             Coffee Shop         Sandwich Place            Breakfast Spot
# 44               Surf Spot                 Market          Sushi Restaurant
# 49  Argentinian Restaurant                 Market               Coffee Shop
# 55            Concert Hall                    Bar     Outdoors & Recreation
# 56                Beer Bar         Breakfast Spot  Mediterranean Restaurant
# 63            Burger Joint        Thai Restaurant            Farmers Market
# 71     Monument / Landmark             Restaurant                       Spa
# 83       Paella Restaurant           Neighborhood                    Bridge
# 91          Sandwich Place           Concert Hall        Mexican Restaurant
#
#    20th Most Common Venue
# 1          Sandwich Place
# 5                     Spa
# 9          Soccer Stadium
# 25            Pizza Place
# 44      Electronics Store
# 49              Bookstore
# 55       Department Store
# 56                    Bar
# 63             Steakhouse
# 71            Coffee Shop
# 83    Japanese Restaurant
# 91           Dessert Shop

# %%
european_city_merged.loc[european_city_merged['Cluster Labels'] == 3, european_city_merged.columns[[0] + list(range(5, european_city_merged.shape[1]))]]
# Out:
#    City_Name 2nd Most Common Venue   3rd Most Common Venue  \
# 6       Bari    Italian Restaurant                     Pub
# 11   Bologna    Italian Restaurant                   Plaza
# 19   Catania           Pizza Place                    Café
# 32  Florence                 Plaza      Italian Restaurant
# 36     Genoa    Italian Restaurant                    Café
# 53     Milan                 Plaza                Boutique
# 59    Naples                 Plaza          Ice Cream Shop
# 62   Palermo                 Plaza             Pizza Place
# 69      Rome         Historic Site          Ice Cream Shop
# 81     Turin                 Plaza  Piedmontese Restaurant
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 6                    Bar                  Café                 Hotel
# 11                  Park                 Hotel                  Café
# 19                 Plaza         Historic Site          Dessert Shop
# 32        Ice Cream Shop     Trattoria/Osteria        Sandwich Place
# 36                 Plaza         Historic Site     Trattoria/Osteria
# 53                Bakery        Ice Cream Shop    Italian Restaurant
# 59           Pizza Place                 Hotel                  Café
# 62                  Café        Ice Cream Shop            Restaurant
# 69                 Hotel    Italian Restaurant              Wine Bar
# 81                  Café                 Hotel           Pizza Place
#
#    7th Most Common Venue          8th Most Common Venue 9th Most Common Venue  \
# 6             Restaurant                 Ice Cream Shop                 Plaza
# 11           Coffee Shop                 Sandwich Place             Bookstore
# 19       Bed & Breakfast  Vegetarian / Vegan Restaurant          Cocktail Bar
# 32                Church                     Art Museum           Art Gallery
# 36    Seafood Restaurant                 Ice Cream Shop          Dessert Shop
# 53           Art Gallery                    Pizza Place                  Park
# 59         Historic Site                          Diner              Wine Bar
# 62                   Bar                  Historic Site                Museum
# 69   Monument / Landmark                 Sandwich Place                Bakery
# 81    Italian Restaurant                   Cocktail Bar   Monument / Landmark
#
#    10th Most Common Venue    11th Most Common Venue 12th Most Common Venue  \
# 6            Cocktail Bar        Seafood Restaurant            Beer Garden
# 11                    Bar  Mediterranean Restaurant      Electronics Store
# 19           Burger Joint                       Pub                 Hostel
# 32               Boutique                    Bakery         Scenic Lookout
# 36          Boat or Ferry                      Park             Steakhouse
# 53             Art Museum       Monument / Landmark            Coffee Shop
# 59                 Castle                Art Museum         History Museum
# 62             Art Museum                       Pub         History Museum
# 69               Fountain                    Church                 Garden
# 81     Seafood Restaurant               Coffee Shop           Dessert Shop
#
#    13th Most Common Venue 14th Most Common Venue 15th Most Common Venue  \
# 6                    Park            Coffee Shop             Steakhouse
# 11               Beer Bar            Pizza Place               Wine Bar
# 19    Japanese Restaurant               Fountain              Bookstore
# 32                    Bar                 Bridge                   Café
# 36    Ligurian Restaurant         Science Museum            Pizza Place
# 53         Sandwich Place           Dessert Shop                Theater
# 59             Restaurant                 Church       Sushi Restaurant
# 62               Tea Room              Gastropub            Art Gallery
# 69                   Café                 Temple                    Bar
# 81         Clothing Store         Scenic Lookout           Cupcake Shop
#
#    16th Most Common Venue 17th Most Common Venue    18th Most Common Venue  \
# 6                 Theater           Gourmet Shop              Cupcake Shop
# 11    Monument / Landmark     Seafood Restaurant            Scenic Lookout
# 19      Trattoria/Osteria                  Hotel  Mediterranean Restaurant
# 32            Pizza Place      Outdoor Sculpture                 Bookstore
# 36              Nightclub                 Bridge              Burger Joint
# 53                   Café           Cocktail Bar          Sushi Restaurant
# 59                    Bar            Coffee Shop                    Bakery
# 62                 Garden           Dessert Shop        Seafood Restaurant
# 69                    Pub             Art Museum          Greek Restaurant
# 81    Japanese Restaurant               Wine Bar             Historic Site
#
#    19th Most Common Venue 20th Most Common Venue
# 6                  Bistro              Gastropub
# 11           Cocktail Bar                 Bistro
# 19     Chinese Restaurant             Steakhouse
# 32         Farmers Market                 Bistro
# 36                 Museum             Lighthouse
# 53                 Museum                 Hostel
# 59           Cupcake Shop              Bookstore
# 62              Wine Shop                 Lounge
# 69       Sushi Restaurant               Boutique
# 81         History Museum                 Bistro

# %%
european_city_merged.loc[european_city_merged['Cluster Labels'] == 4, european_city_merged.columns[[0] + list(range(5, european_city_merged.shape[1]))]]
# Out:
#       City_Name          2nd Most Common Venue 3rd Most Common Venue  \
# 2     Amsterdam                          Hotel                   Bar
# 3       Antwerp                 Clothing Store                   Bar
# 7        Berlin                      Bookstore                 Hotel
# 8     Bielefeld                    Supermarket                  Café
# 10       Bochum                         Bakery               Theater
# 14       Bremen             Italian Restaurant                   Bar
# 16    Bucharest                          Hotel                 Plaza
# 17     Budapest                         Bakery                 Hotel
# 18    Bydgoszcz                     Restaurant                  Café
# 20  Cluj-Napoca                         Bakery                   Gym
# 21      Cologne                          Hotel                 Plaza
# 22    Constanța                  Boat or Ferry                Lounge
# 23   Copenhagen                    Coffee Shop              Wine Bar
# 24      Craiova                            Bar                  Café
# 31        Essen                           Café                 Hotel
# 34       Galați                    Pizza Place                  Park
# 35       Gdańsk                           Café           Pizza Place
# 37   Gothenburg                            Pub           Coffee Shop
# 38      Hamburg                    Coffee Shop    Italian Restaurant
# 40     Helsinki                          Hotel                  Café
# 43       Kraków                          Hotel           Coffee Shop
# 47       Lublin                          Hotel                  Park
# 65      Plovdiv                           Café           Supermarket
# 68         Riga                          Plaza           Coffee Shop
# 70    Rotterdam                          Hotel                  Café
# 72        Sofia                        Theater           Coffee Shop
# 73    Stockholm                          Hotel                  Café
# 74    Stuttgart                            Bar           Coffee Shop
# 76      Tallinn                 Scenic Lookout              Wine Bar
# 77    The Hague                            Bar                  Park
# 82      Utrecht                            Bar           Coffee Shop
# 84        Varna                           Café             Beach Bar
# 86      Vilnius                           Café                   Gym
# 87       Warsaw  Vegetarian / Vegan Restaurant                  Park
# 88      Wrocław                  Grocery Store            Restaurant
# 92         Łódź                    Coffee Shop                   Bar
#
#             4th Most Common Venue      5th Most Common Venue  \
# 2                      Restaurant                     Bakery
# 3                           Plaza               Cocktail Bar
# 7                      Art Museum        Monument / Landmark
# 8                            Park  Middle Eastern Restaurant
# 10                 Ice Cream Shop                   Bus Stop
# 14                           Café                Supermarket
# 16            Romanian Restaurant                  Gastropub
# 17                    Pizza Place                 Playground
# 18               Sushi Restaurant       Fast Food Restaurant
# 20                           Café                      Hotel
# 21             Italian Restaurant           Pedestrian Plaza
# 22                    Pizza Place       Gym / Fitness Center
# 23                           Park    Scandinavian Restaurant
# 24                     Restaurant                        Pub
# 31                     Restaurant                     Bakery
# 34                           Café                     Lounge
# 35                  Historic Site                     Hostel
# 37                           Café    Scandinavian Restaurant
# 38  Vegetarian / Vegan Restaurant                       Café
# 40                           Park                Coffee Shop
# 43           Gym / Fitness Center          Food & Drink Shop
# 47                 Rental Service          Recreation Center
# 65                            Bar                      Hotel
# 68                            Bar                       Café
# 70                    Pizza Place                Zoo Exhibit
# 72             Italian Restaurant                     Bakery
# 73                         Bakery                Coffee Shop
# 74                          Plaza         Italian Restaurant
# 76                     Restaurant               Cocktail Bar
# 77                          Hotel             Breakfast Spot
# 82                 Ice Cream Shop                       Park
# 84                    Coffee Shop       Bulgarian Restaurant
# 86           Gym / Fitness Center                       Park
# 87                    Coffee Shop                       Café
# 88                         Bistro                Coffee Shop
# 92             Italian Restaurant                       Café
#
#    6th Most Common Venue          7th Most Common Venue  \
# 2     Italian Restaurant                          Plaza
# 3      French Restaurant             Belgian Restaurant
# 7           Concert Hall                          Plaza
# 8                  Hotel               Asian Restaurant
# 10                  Park                   Intersection
# 14             Drugstore                 Ice Cream Shop
# 16                   Pub                     Restaurant
# 17   Indie Movie Theater                        Theater
# 18           Coffee Shop                 Clothing Store
# 20                Bistro                     Restaurant
# 21                  Park                   Cocktail Bar
# 22    Italian Restaurant                            Gym
# 23          Cocktail Bar                         Bakery
# 24           Supermarket                           Park
# 31           Pizza Place             Italian Restaurant
# 34                 Hotel    Eastern European Restaurant
# 35          Cocktail Bar                 History Museum
# 37          Burger Joint  Vegetarian / Vegan Restaurant
# 38            Restaurant                          Plaza
# 40     French Restaurant                       Wine Bar
# 43         Go Kart Track                  Grocery Store
# 47         Train Station                 Soccer Stadium
# 65         Historic Site                        Brewery
# 68            Restaurant                          Hotel
# 70        Sandwich Place                         Bakery
# 72          Dessert Shop                      Bookstore
# 73        Clothing Store                      Bookstore
# 74                  Café                 Ice Cream Shop
# 76                  Café                            Pub
# 77            Restaurant                         Bakery
# 82          Burger Joint                   Concert Hall
# 84                 Plaza                          Beach
# 86                Bakery                 Scenic Lookout
# 87                 Plaza                   Dessert Shop
# 88      Sushi Restaurant                   Tram Station
# 92            Restaurant                     Steakhouse
#
#             8th Most Common Venue          9th Most Common Venue  \
# 2                           Canal                           Café
# 3                          Bakery                       Boutique
# 7                            Park                  Historic Site
# 8              Italian Restaurant                   Burger Joint
# 10                   Concert Hall               Tapas Restaurant
# 14              German Restaurant             Falafel Restaurant
# 16                         Bakery                   Dessert Shop
# 17                   Dessert Shop             Italian Restaurant
# 18    Eastern European Restaurant                  Historic Site
# 20                 Breakfast Spot                           Park
# 21                    Coffee Shop               Sushi Restaurant
# 22                           Café                         Bistro
# 23                          Hotel                   Burger Joint
# 24           Fast Food Restaurant                         Lounge
# 31                   Burger Joint               Doner Restaurant
# 34                  Shopping Mall                    Coffee Shop
# 35             Chinese Restaurant  Vegetarian / Vegan Restaurant
# 37          Vietnamese Restaurant              German Restaurant
# 38                     Steakhouse                    Art Gallery
# 40                       Beer Bar            Indie Movie Theater
# 43                            Gym                           Café
# 47                           Café                  Grocery Store
# 65                          Diner                     Restaurant
# 68                        Theater                    Art Gallery
# 70  Vegetarian / Vegan Restaurant                           Park
# 72                     Beer Store                            Bar
# 73                           Park                       Wine Bar
# 74                   Cocktail Bar           Fast Food Restaurant
# 76                           Park                       Beer Bar
# 77                        Theater                Thai Restaurant
# 82                          Plaza              French Restaurant
# 84                          Hotel                         Bakery
# 86                          Plaza                   Dessert Shop
# 87               Sushi Restaurant                         Bakery
# 88    Eastern European Restaurant                  Train Station
# 92                           Park               Sushi Restaurant
#
#          10th Most Common Venue         11th Most Common Venue  \
# 2                 Deli / Bodega                Organic Grocery
# 3                       Theater                         Bistro
# 7             Outdoor Sculpture                         Bakery
# 8                  Tram Station       Mediterranean Restaurant
# 10            German Restaurant               Sushi Restaurant
# 14                   Restaurant                          Plaza
# 16                    Bookstore                    Pizza Place
# 17               Breakfast Spot           Gym / Fitness Center
# 18                      Stadium                 Ice Cream Shop
# 20                          Pub                   Cocktail Bar
# 21                Movie Theater                     Restaurant
# 22                  Coffee Shop       Mediterranean Restaurant
# 23                         Café                 Ice Cream Shop
# 24           Italian Restaurant               Greek Restaurant
# 31                          Pub                            Bar
# 34                 Cocktail Bar           Fast Food Restaurant
# 35  Eastern European Restaurant                       Beer Bar
# 37           Seafood Restaurant                     Restaurant
# 38                         Park                   Cocktail Bar
# 40             Asian Restaurant               Sushi Restaurant
# 43                   Restaurant              Electronics Store
# 47                Jewelry Store         Furniture / Home Store
# 65                     Fountain                            Pub
# 68                          Spa                     Beer Store
# 70                Deli / Bodega                 Ice Cream Shop
# 72                 Cocktail Bar                           Café
# 73                 Cocktail Bar                            Pub
# 74            German Restaurant                          Hotel
# 76                      Theater  Vegetarian / Vegan Restaurant
# 77                        Plaza                     Art Museum
# 82                        Hotel                            Pub
# 84         Gym / Fitness Center             Italian Restaurant
# 86                   Restaurant                         Museum
# 87                 Cocktail Bar                        Theater
# 88                  Gas Station                           Park
# 92                      Theater                            Pub
#
#    12th Most Common Venue        13th Most Common Venue  \
# 2    Marijuana Dispensary                  Dessert Shop
# 3      Italian Restaurant                 Women's Store
# 7             Art Gallery         Vietnamese Restaurant
# 8                  Bakery                    Restaurant
# 10       Asian Restaurant                          Café
# 14          Burrito Place                        Bakery
# 16              Roof Deck                  Cocktail Bar
# 17              Wine Shop                  Gourmet Shop
# 18            Gas Station                       Theater
# 20     Italian Restaurant                         Plaza
# 21                    Bar    Modern European Restaurant
# 22              Nightclub              Greek Restaurant
# 23             Art Museum                        Palace
# 24            Pizza Place   Eastern European Restaurant
# 31       Greek Restaurant                     Drugstore
# 34              Hotel Bar                Gymnastics Gym
# 35            Coffee Shop                  Concert Hall
# 37                 Bistro  Theme Park Ride / Attraction
# 38                Theater                  Concert Hall
# 40         Farmers Market                           Bar
# 43         Clothing Store                          Park
# 47    Japanese Restaurant            Italian Restaurant
# 65       Greek Restaurant            Turkish Restaurant
# 68         Scenic Lookout                  Burger Joint
# 70                 Market                         Plaza
# 72                  Hotel                   Yoga Studio
# 73                    Bar                      Beer Bar
# 74       Sushi Restaurant                    Restaurant
# 76       Asian Restaurant                   Coffee Shop
# 77         Sandwich Place                 Shopping Mall
# 82     Italian Restaurant      Mediterranean Restaurant
# 84             Restaurant            Seafood Restaurant
# 86                  Hotel                   Pizza Place
# 87         Clothing Store                   Pizza Place
# 88            Supermarket             Electronics Store
# 92    Japanese Restaurant            Turkish Restaurant
#
#         14th Most Common Venue         15th Most Common Venue  \
# 2         Caribbean Restaurant                         Museum
# 3               Lingerie Store             Frozen Yogurt Shop
# 7              Organic Grocery                        Theater
# 8            German Restaurant                          Plaza
# 10                     Butcher                   Burger Joint
# 14                        Park                   Burger Joint
# 16                        Café                         Bistro
# 17               Historic Site                       Tea Room
# 18                 Supermarket     Modern European Restaurant
# 20                Dessert Shop                    Art Gallery
# 21                      Museum          Vietnamese Restaurant
# 22          Salon / Barbershop                            Bar
# 23      Furniture / Home Store                          Plaza
# 24               Bowling Alley                 Clothing Store
# 31          Falafel Restaurant             Turkish Restaurant
# 34          Chinese Restaurant                    Supermarket
# 35           Polish Restaurant                 Ice Cream Shop
# 37                Liquor Store                   Gourmet Shop
# 38  Modern European Restaurant                      Bookstore
# 40                 Art Gallery                         Bakery
# 43        Fast Food Restaurant                    Pizza Place
# 47            Recording Studio              Polish Restaurant
# 65        Bulgarian Restaurant             Italian Restaurant
# 68              Cosmetics Shop                      Multiplex
# 70                 Supermarket                     Art Museum
# 72                      Garden                    Art Gallery
# 73              History Museum                   Burger Joint
# 74                      Bakery                       Tea Room
# 76          Italian Restaurant                   Dance Studio
# 77          Italian Restaurant                    Supermarket
# 82                      Museum  Vegetarian / Vegan Restaurant
# 84  Modern European Restaurant           Fast Food Restaurant
# 86                   Bookstore             Italian Restaurant
# 87             Thai Restaurant              Polish Restaurant
# 88        Gym / Fitness Center                 Clothing Store
# 92                      Bistro  Vegetarian / Vegan Restaurant
#
#            16th Most Common Venue     17th Most Common Venue  \
# 2                    Cocktail Bar                    Theater
# 3                       Bookstore            Bubble Tea Shop
# 7                          Bistro             Ice Cream Shop
# 8                          Garden           Sushi Restaurant
# 10                      Bookstore             Scenic Lookout
# 14      Middle Eastern Restaurant                       Lake
# 16                    Supermarket                       Park
# 17                           Park                      Plaza
# 18                 Breakfast Spot               Burger Joint
# 20           Gym / Fitness Center                  Nightclub
# 21                     Art Museum                  Gastropub
# 22                          Beach               Cocktail Bar
# 23             Seafood Restaurant              Movie Theater
# 24               Department Store                Coffee Shop
# 31                    Coffee Shop          Trattoria/Osteria
# 34               Botanical Garden                     Garden
# 35                          Plaza                        Bar
# 37                 Ice Cream Shop        Indie Movie Theater
# 38          Vietnamese Restaurant             Ice Cream Shop
# 40            Filipino Restaurant  Middle Eastern Restaurant
# 43                     Food Truck                 Theme Park
# 47                           Pool                 Eye Doctor
# 65                   Cocktail Bar             Soccer Stadium
# 68                       Wine Bar         Italian Restaurant
# 70                      Gastropub         Italian Restaurant
# 72  Vegetarian / Vegan Restaurant                Pizza Place
# 73            Szechuan Restaurant                Beer Garden
# 74                    Supermarket            Thai Restaurant
# 76                          Plaza                  Bookstore
# 77          Indonesian Restaurant          Electronics Store
# 82                       Beer Bar        Indie Movie Theater
# 84                    Supermarket                       Park
# 86                       Beer Bar                  Wine Shop
# 87                 Breakfast Spot                 Steakhouse
# 88                    Pizza Place               Climbing Gym
# 92                     Art Museum                Art Gallery
#
#     18th Most Common Venue         19th Most Common Venue  \
# 2        French Restaurant                   Burger Joint
# 3   Furniture / Home Store                       Friterie
# 7           History Museum                   Gourmet Shop
# 8               Steakhouse               Tapas Restaurant
# 10                Beer Bar              Food & Drink Shop
# 14                  Market                 Soccer Stadium
# 16               Monastery             Italian Restaurant
# 17          Sandwich Place                     Restaurant
# 18               Multiplex                         Museum
# 20                Wine Bar                         Lounge
# 21    Gym / Fitness Center              German Restaurant
# 22      Turkish Restaurant                          Hotel
# 23             Pizza Place                        Library
# 24            Cocktail Bar            Sporting Goods Shop
# 31       Food & Drink Shop            Indie Movie Theater
# 34                 Factory                         Market
# 35      Mexican Restaurant                  Shopping Mall
# 37             Record Shop                       Wine Bar
# 38      Salon / Barbershop                   Gourmet Shop
# 40        Toy / Game Store  Vegetarian / Vegan Restaurant
# 43                 Theater                    Bus Station
# 47      English Restaurant                    Escape Room
# 65            Dessert Shop           Fast Food Restaurant
# 68    Gym / Fitness Center  Vegetarian / Vegan Restaurant
# 70            Burger Joint            Sporting Goods Shop
# 72     Arts & Crafts Store                          Plaza
# 73      Falafel Restaurant                     Shoe Store
# 74              Steakhouse          Vietnamese Restaurant
# 76       French Restaurant                            Bar
# 77                    Café                 Ice Cream Shop
# 82                    Farm                 Sandwich Place
# 84               BBQ Joint                            Gym
# 86                     Bar                       Boutique
# 87                  Market          Street Food Gathering
# 88                  Lounge                  Big Box Store
# 92             Pizza Place                          Diner
#
#            20th Most Common Venue
# 2                  Chocolate Shop
# 3                  Breakfast Spot
# 7                      Restaurant
# 8                   Big Box Store
# 10                       Mountain
# 14                   Soccer Field
# 16                        Theater
# 17              Outdoor Sculpture
# 18                  Shopping Mall
# 20                      Bookstore
# 21                   Dessert Shop
# 22                   Cupcake Shop
# 23               Sushi Restaurant
# 24                      Gastropub
# 31  Vegetarian / Vegan Restaurant
# 34              French Restaurant
# 35                       Fountain
# 37              French Restaurant
# 38                            Pub
# 40                      Bookstore
# 43                  Shopping Mall
# 47           Ethiopian Restaurant
# 65                    Snack Place
# 68             Salon / Barbershop
# 70             Salon / Barbershop
# 72                         Bistro
# 73             Seafood Restaurant
# 74                 Scenic Lookout
# 76         Furniture / Home Store
# 77                       Beer Bar
# 82                         Bistro
# 84                 Clothing Store
# 86               Sushi Restaurant
# 87                      Bookstore
# 88                      Bookstore
# 92                 Ice Cream Shop
